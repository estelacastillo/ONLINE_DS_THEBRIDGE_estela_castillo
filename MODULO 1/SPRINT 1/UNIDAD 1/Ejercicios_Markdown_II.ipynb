# %% [markdown]
# >EJERCICIO6: LISTAS

# %% [markdown]
# * Manzanas
# * Plátanos
# * Uvas

# %% [markdown]
# 1. Arbol binario
# 2. Random Forest
# 3. Regresion Logística

# %% [markdown]
# >EJERCICIO7: LISTAS ANIDADAS

# %% [markdown]
# Frutas y Verduras
# 1. Frutas
#    * Manzanas
#    * Peras
#    * Kiwis
# 2. Verduras
#    * Judias verdes
#    * Acelgas
#    * Alcachofas

# %% [markdown]
# >EJERCICIO8: ENLACES E IMÁGENES

# %% [markdown]
# <p><a href="www.thebridge.com">Por aquí se cruzan puentes</a>

# %% [markdown]
# ![Logo](attachment:1009b765-b8b8-4e40-bd27-efbd590744bc.png)

# %% [markdown]
# >EJERCICIO9: LÍNEAS HORIZONTALES Y BLOQUES DE CÓDIGO

# %% [markdown]
# ***
# print("Hola Mundo")
#
# ---
